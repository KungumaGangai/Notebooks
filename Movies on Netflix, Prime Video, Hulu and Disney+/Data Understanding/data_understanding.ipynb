# %% [markdown]
# # Data Understanding

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.2-cp38-cp38-win_amd64.whl (10.6 MB)
# Collecting pytz>=2020.1
#   Downloading pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in e:\anaconda3\envs\venv_netflix_prime_hulu_disney\lib\site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.18.5
#   Downloading numpy-1.22.4-cp38-cp38-win_amd64.whl (14.8 MB)
# Requirement already satisfied: six>=1.5 in e:\anaconda3\envs\venv_netflix_prime_hulu_disney\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.22.4 pandas-1.4.2 pytz-2022.1

# %%
import pandas as pd

# %%
# data = pd.read_csv("E:/Personal-Project/Data Science Projects/Datasets/kaggle/Movies on Netflix, Prime Video, Hulu and Disney+/archive/MoviesOnStreamingPlatforms.csv")
data = pd.read_csv("E:/Personal-Project/Data Science Projects/Datasets/kaggle/Movies on Netflix, Prime Video, Hulu and Disney+/MoviesOnStreamingPlatforms_updated.csv/MoviesOnStreamingPlatforms_updated.csv")
data.head()
# Out:
#    Unnamed: 0  ID                                     Title  Year  Age  \
# 0           0   1                              The Irishman  2019  18+
# 1           1   2                                    Dangal  2016   7+
# 2           2   3  David Attenborough: A Life on Our Planet  2020   7+
# 3           3   4         Lagaan: Once Upon a Time in India  2001   7+
# 4           4   5                                      Roma  2018  18+
#
#      IMDb Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0  7.8/10          98/100        1     0            0        0     0
# 1  8.4/10          97/100        1     0            0        0     0
# 2  9.0/10          95/100        1     0            0        0     0
# 3  8.1/10          94/100        1     0            0        0     0
# 4  7.7/10          94/100        1     0            0        0     0
#
#                                            Directors  \
# 0                                    Martin Scorsese
# 1                                      Nitesh Tiwari
# 2  Alastair Fothergill,Jonathan Hughes,Keith Scholey
# 3                                 Ashutosh Gowariker
# 4                                                NaN
#
#                              Genres  \
# 0             Biography,Crime,Drama
# 1      Action,Biography,Drama,Sport
# 2             Documentary,Biography
# 3               Drama,Musical,Sport
# 4  Action,Drama,History,Romance,War
#
#                                              Country  \
# 0                                      United States
# 1  India,United States,United Kingdom,Australia,K...
# 2                                     United Kingdom
# 3                               India,United Kingdom
# 4                       United Kingdom,United States
#
#                                Language  Runtime
# 0  English,Italian,Latin,Spanish,German    209.0
# 1                         Hindi,English    161.0
# 2                               English     83.0
# 3                         Hindi,English    224.0
# 4                               English     52.0

# %%
# Use index_col=[0] argument in read_csv() function to remove 'Unnamed: 0' column from the data variable.

# Unnamed: 0 column in pandas comes when you are reading CSV file . 
# The simplest solution would be to read the "Unnamed: 0" column as the index.

# df = pd.read_csv("E:/Personal-Project/Data Science Projects/Datasets/kaggle/Movies on Netflix, Prime Video, Hulu and Disney+/archive/MoviesOnStreamingPlatforms.csv", index_col=[0])
# df.head()

# Another way 
# Remove column 'Unnamed: 0' using drop() function
df = data 
df.drop(['Unnamed: 0', 'ID'], axis = 1, inplace=True)
df.head()
# Out:
#                                       Title  Year  Age    IMDb  \
# 0                              The Irishman  2019  18+  7.8/10
# 1                                    Dangal  2016   7+  8.4/10
# 2  David Attenborough: A Life on Our Planet  2020   7+  9.0/10
# 3         Lagaan: Once Upon a Time in India  2001   7+  8.1/10
# 4                                      Roma  2018  18+  7.7/10
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0          98/100        1     0            0        0     0
# 1          97/100        1     0            0        0     0
# 2          95/100        1     0            0        0     0
# 3          94/100        1     0            0        0     0
# 4          94/100        1     0            0        0     0
#
#                                            Directors  \
# 0                                    Martin Scorsese
# 1                                      Nitesh Tiwari
# 2  Alastair Fothergill,Jonathan Hughes,Keith Scholey
# 3                                 Ashutosh Gowariker
# 4                                                NaN
#
#                              Genres  \
# 0             Biography,Crime,Drama
# 1      Action,Biography,Drama,Sport
# 2             Documentary,Biography
# 3               Drama,Musical,Sport
# 4  Action,Drama,History,Romance,War
#
#                                              Country  \
# 0                                      United States
# 1  India,United States,United Kingdom,Australia,K...
# 2                                     United Kingdom
# 3                               India,United Kingdom
# 4                       United Kingdom,United States
#
#                                Language  Runtime
# 0  English,Italian,Latin,Spanish,German    209.0
# 1                         Hindi,English    161.0
# 2                               English     83.0
# 3                         Hindi,English    224.0
# 4                               English     52.0

# %%
# Get column names in dataframe
df.columns
# Out:
# Index(['Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Netflix', 'Hulu',
#        'Prime Video', 'Disney+', 'Type', 'Directors', 'Genres', 'Country',
#        'Language', 'Runtime'],
#       dtype='object')

# %% [markdown]
# #### Column names in the Dataframe
#     ID         - Indicates a single Row in the dataframe (unique value)
#     Title      - Name of the Movie/Film (unique value)
#     Year       - Release Year of the Movie
#     Age        - Permitted Age to watch a movie
#     Rotten Tomatoes - Review of rate of a movie
#     Netflix    - If movie is available in netflix
#     Hulu       - If movie is available in hulu
#     Prime Video - If movie is available in Prime video
#     Disney+    - If movie is available in Disney+
#     Type       - Unknown
#     Directors  - Name of the Director
#     Genres     - Genres of the movie
#     Country    - Name of the Countries the movies are running
#     Language   - Name of the languages the movies are released in.
#     Runtime    - Total runtime of the movie.

# %%
# Datatype of each column
df.dtypes
# Out:
# Title               object
# Year                 int64
# Age                 object
# IMDb                object
# Rotten Tomatoes     object
# Netflix              int64
# Hulu                 int64
# Prime Video          int64
# Disney+              int64
# Type                 int64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object

# %%
# Total columns and rows
df.shape
# Out:
# (9515, 15)

# %%
df1 = df[['Title', 'Directors', 'Country']]
df1.head(10)
# Out:
#                                       Title  \
# 0                              The Irishman
# 1                                    Dangal
# 2  David Attenborough: A Life on Our Planet
# 3         Lagaan: Once Upon a Time in India
# 4                                      Roma
# 5         To All the Boys I've Loved Before
# 6                        The Social Dilemma
# 7                                      Okja
# 8              The Ballad of Buster Scruggs
# 9                The Trial of the Chicago 7
#
#                                            Directors  \
# 0                                    Martin Scorsese
# 1                                      Nitesh Tiwari
# 2  Alastair Fothergill,Jonathan Hughes,Keith Scholey
# 3                                 Ashutosh Gowariker
# 4                                                NaN
# 5                                      Susan Johnson
# 6                                      Jeff Orlowski
# 7                                       Bong Joon Ho
# 8                               Ethan Coen,Joel Coen
# 9                                       Aaron Sorkin
#
#                                              Country
# 0                                      United States
# 1  India,United States,United Kingdom,Australia,K...
# 2                                     United Kingdom
# 3                               India,United Kingdom
# 4                       United Kingdom,United States
# 5                                      United States
# 6                                      United States
# 7                          South Korea,United States
# 8                                      United States
# 9                 United States,United Kingdom,India

# %% [markdown]
# #### IMDB datasets
#     https://www.kaggle.com/datasets/komalkhetlani/imdb-dataset
#     https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
#
# #### Netflix dataset
#     https://www.kaggle.com/datasets/pariaagharabi/netflix2020

# %% [markdown]
# #### Dataset Source
#     https://www.kaggle.com/code/ruchi798/movies-and-tv-shows-eda/data?select=MoviesOnStreamingPlatforms_updated.csv
